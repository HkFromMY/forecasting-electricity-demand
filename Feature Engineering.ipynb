# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def is_weekend(dayofweek):
  if dayofweek in [5, 6]:
    return 1
  
  return 0

def season(month):
  """
  Mapping
    1: Spring
    2: Summer
    3: Autumn
    4: Winter
  """

  if 3 <= month <= 5:
    # spring
    return 1
  
  elif 6 <= month <= 8:
    # summer
    return 2
  
  elif 9 <= month <= 11:
    # autumn
    return 3
  
  elif month in [12, 1, 2]:
    # winter
    return 4
  
def at_home(hour):
    if 8 <= hour <= 17:
        # if the time is between 8:00 A.M. and 5:00 P.M., then the occupants most probably outside
        return 0
    
    else:
        return 1
  
def no_work(dayofweek, holiday):
  if dayofweek in [5, 6] or holiday != "No Holiday":
    # if it's weekend or got holiday
    return 1
  
  else:
    return 0

# %%
df = pd.read_csv("cleaned_data\\final_merged_dataset.csv", parse_dates=['tstp'])

# %%
# date-based features
df['year'] = df['tstp'].dt.year
df['month'] = df['tstp'].dt.month
df['day'] = df['tstp'].dt.day
df['dayofweek_num'] = df['tstp'].dt.dayofweek
df['is_weekend'] = df['dayofweek_num'].apply(is_weekend)
df['season'] = df['month'].apply(season)

vectorized_noWork = np.vectorize(no_work)
df['no_work'] = vectorized_noWork(df['dayofweek_num'], df['Type'])

# %%
df[['tstp', 'year', 'month', 'day', 'dayofweek_num', 'is_weekend', 'season', 'no_work']].sample(100)
# Out:
#                       tstp  year  month  day  dayofweek_num  is_weekend  \
# 526009 2013-05-04 08:00:00  2013      5    4              5           1
# 104252 2012-12-29 16:00:00  2012     12   29              5           1
# 89766  2012-09-10 19:00:00  2012      9   10              0           0
# 657024 2012-08-13 02:00:00  2012      8   13              0           0
# 604099 2012-06-10 17:00:00  2012      6   10              6           1
# ...                    ...   ...    ...  ...            ...         ...
# 88691  2012-07-28 00:00:00  2012      7   28              5           1
# 388842 2013-03-06 10:00:00  2013      3    6              2           0
# 285359 2012-11-23 04:00:00  2012     11   23              4           0
# 365407 2013-09-28 06:00:00  2013      9   28              5           1
# 404666 2013-07-16 06:00:00  2013      7   16              1           0
#
#         season  no_work
# 526009       1        1
# 104252       4        1
# 89766        3        0
# 657024       2        0
# 604099       2        1
# ...        ...      ...
# 88691        2        1
# 388842       1        0
# 285359       3        0
# 365407       3        1
# 404666       2        0
#
# [100 rows x 8 columns]

# %%
# time-based features
df['hour'] = df['tstp'].dt.hour

vectorized_outsideWorkingHour = np.vectorize(at_home)
df['at_home'] = vectorized_outsideWorkingHour(df['hour'])

# %%
df[['tstp', 'hour', 'at_home']]
# Out:
#                       tstp  hour  at_home
# 0      2012-10-16 10:00:00    10        0
# 1      2012-10-16 11:00:00    11        0
# 2      2012-10-16 12:00:00    12        0
# 3      2012-10-16 13:00:00    13        0
# 4      2012-10-16 14:00:00    14        0
# ...                    ...   ...      ...
# 764121 2014-01-31 20:00:00    20        1
# 764122 2014-01-31 21:00:00    21        1
# 764123 2014-01-31 22:00:00    22        1
# 764124 2014-01-31 23:00:00    23        1
# 764125 2014-02-01 00:00:00     0        1
#
# [764126 rows x 3 columns]

# %%
household_ids = df['LCLid'].unique()
household_dfs = []

grp_obj = df.groupby(['LCLid'])
for household_id in household_ids:
    # get the single house hold dataframe
    single_df = grp_obj.get_group(household_id).sort_values(by='tstp')
    
    for i in range(24):
        single_df.loc[:, f'shifted_energy_{i + 1}h'] = single_df['energy(kWh/hh)'].shift(i + 1)

    single_df['rolling_mean_energy_6h'] = single_df['energy(kWh/hh)'].rolling(6).mean()
    single_df['rolling_mean_energy_12h'] = single_df['energy(kWh/hh)'].rolling(12).mean()
    single_df['rolling_mean_energy_18h'] = single_df['energy(kWh/hh)'].rolling(18).mean()
    single_df['rolling_mean_energy_24h'] = single_df['energy(kWh/hh)'].rolling(24).mean()
    household_dfs.append(single_df)

# concatenate all partitioned dataframes
df = pd.concat(household_dfs)

# %%
df[['tstp', 'LCLid', 'dayofweek_num', 'hour', 'energy(kWh/hh)', 'shifted_energy_1h', 'shifted_energy_2h', 'shifted_energy_3h', 'rolling_mean_energy_24h']].iloc[:24]
# Out:
#                   tstp      LCLid  dayofweek_num  hour  energy(kWh/hh)  \
# 0  2012-10-16 10:00:00  MAC003686              1    10           0.317
# 1  2012-10-16 11:00:00  MAC003686              1    11           0.801
# 2  2012-10-16 12:00:00  MAC003686              1    12           0.557
# 3  2012-10-16 13:00:00  MAC003686              1    13           0.548
# 4  2012-10-16 14:00:00  MAC003686              1    14           0.549
# 5  2012-10-16 15:00:00  MAC003686              1    15           0.214
# 6  2012-10-16 16:00:00  MAC003686              1    16           0.358
# 7  2012-10-16 17:00:00  MAC003686              1    17           1.055
# 8  2012-10-16 18:00:00  MAC003686              1    18           1.503
# 9  2012-10-16 19:00:00  MAC003686              1    19           0.972
# 10 2012-10-16 20:00:00  MAC003686              1    20           0.792
# 11 2012-10-16 21:00:00  MAC003686              1    21           0.452
# 12 2012-10-16 22:00:00  MAC003686              1    22           0.220
# 13 2012-10-16 23:00:00  MAC003686              1    23           0.215
# 14 2012-10-17 00:00:00  MAC003686              2     0           0.209
# 15 2012-10-17 01:00:00  MAC003686              2     1           0.225
# 16 2012-10-17 02:00:00  MAC003686              2     2           0.197
# 17 2012-10-17 03:00:00  MAC003686              2     3           0.210
# 18 2012-10-17 04:00:00  MAC003686              2     4           0.218
# 19 2012-10-17 05:00:00  MAC003686              2     5           0.290
# 20 2012-10-17 06:00:00  MAC003686              2     6           0.583
# 21 2012-10-17 07:00:00  MAC003686              2     7           0.892
# 22 2012-10-17 08:00:00  MAC003686              2     8           0.261
# 23 2012-10-17 09:00:00  MAC003686              2     9           0.224
#
#     shifted_energy_1h  shifted_energy_2h  shifted_energy_3h  \
# 0                 NaN                NaN                NaN
# 1               0.317                NaN                NaN
# 2               0.801              0.317                NaN
# 3               0.557              0.801              0.317
# 4               0.548              0.557              0.801
# 5               0.549              0.548              0.557
# 6               0.214              0.549              0.548
# 7               0.358              0.214              0.549
# 8               1.055              0.358              0.214
# 9               1.503              1.055              0.358
# 10              0.972              1.503              1.055
# 11              0.792              0.972              1.503
# 12              0.452              0.792              0.972
# 13              0.220              0.452              0.792
# 14              0.215              0.220              0.452
# 15              0.209              0.215              0.220
# 16              0.225              0.209              0.215
# 17              0.197              0.225              0.209
# 18              0.210              0.197              0.225
# 19              0.218              0.210              0.197
# 20              0.290              0.218              0.210
# 21              0.583              0.290              0.218
# 22              0.892              0.583              0.290
# 23              0.261              0.892              0.583
#
#     rolling_mean_energy_24h
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                  0.49425

# %%
# drop all missing values
df = df.dropna()

# %%
allnull = df.isna().sum()
allnull.loc[allnull > 0]
# Out:
# Series([], dtype: int64)

# %%
df.columns
# Out:
# Index(['tstp', 'energy(kWh/hh)', 'LCLid', 'stdorToU', 'Acorn', 'visibility',
#        'windBearing', 'temperature', 'dewPoint', 'pressure',
#        'apparentTemperature', 'windSpeed', 'precipType', 'humidity', 'summary',
#        'DIGITAL_Internet Access: Usage in Last Week_20 hours or more',
#        'DIGITAL_Internet Access: Usage in Last Week_3-7 hours',
#        'DIGITAL_Internet Access: Usage in Last Week_8-19 hours',
#        'DIGITAL_Internet Access: Usage in Last Week_Less than 2 hours',
#        'DIGITAL_Internet Access: Usage in Last Week_Not at all',
#        'DIGITAL_TV on Demand_Watch on a Mobile phone/Device',
#        'DIGITAL_TV on Demand_Watch on a PC',
#        'DIGITAL_TV on Demand_Watch on a TV set',
#        'ECONOMY_Economic Activity_Employee Full-Time',
#        'ECONOMY_Economic Activity_Employee Part-Time',
#        'ECONOMY_Economic Activity_Retired',
#        'ECONOMY_Economic Activity_Self-employed',
#        'ECONOMY_Economic Activity_Student',
#        'ECONOMY_Economic Activity_Unemployed and seeking work',
#        'ECONOMY_Occupation_Retired', 'ECONOMY_Occupation_Student',
#        'ECONOMY_Occupation_Unemployed',
#        'ENVIRONMENT_Action_Make an effort to cut down on the use of gas/electricity at home',
#        'ENVIRONMENT_Action_Rarely Leave TV or PC on standby for long periods of time at home',
#        'ENVIRONMENT_Action_Rarely leave the mobile phone charger in the socket when not in use',
#        'FAMILY_Household Size_Household size : 1 person',
#        'FAMILY_Household Size_Household size : 2 persons',
#        'FAMILY_Household Size_Household size : 3-4 persons',
#        'FAMILY_Household Size_Household size : 5+ persons',
#        'FINANCE_Financial Channel: Manage Current Account_Online at home or work',
#        'FINANCE_Financial Channel: Manage Savings Account_Online at home or work',
#        'FINANCE_Household Annual Income_£0-£20,000',
#        'FINANCE_Household Annual Income_£100,000+',
#        'FINANCE_Household Annual Income_£20,000-£40,000',
#        'FINANCE_Household Annual Income_£40,000-£60,000',
#        'FINANCE_Household Annual Income_£60,000-£80,000',
#        'FINANCE_Household Annual Income_£80,000-£100,000',
#        'LEISURE TIME_Magazines Read_Computers and Electrical', 'date', 'Type',
#        'year', 'month', 'day', 'dayofweek_num', 'is_weekend', 'season',
#        'no_work', 'hour', 'at_home', 'shifted_energy_1h', 'shifted_energy_2h',
#        'shifted_energy_3h', 'shifted_energy_4h', 'shifted_energy_5h',
#        'shifted_energy_6h', 'shifted_energy_7h', 'shifted_energy_8h',
#        'shifted_energy_9h', 'shifted_energy_10h', 'shifted_energy_11h',
#        'shifted_energy_12h', 'shifted_energy_13h', 'shifted_energy_14h',
#        'shifted_energy_15h', 'shifted_energy_16h', 'shifted_energy_17h',
#        'shifted_energy_18h', 'shifted_energy_19h', 'shifted_energy_20h',
#        'shifted_energy_21h', 'shifted_energy_22h', 'shifted_energy_23h',
#        'shifted_energy_24h', 'rolling_mean_energy_6h',
#        'rolling_mean_energy_12h', 'rolling_mean_energy_18h',
#        'rolling_mean_energy_24h'],
#       dtype='object')

# %%
df.to_csv("cleaned_data\\24timestep1h.csv", index=False)

# %%
df.to_csv("cleaned_data\\cleaned_df.csv", index=False)
